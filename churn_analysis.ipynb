# %%
import pandas as pd

# %%
df = pd.read_csv("../data/customer_churn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/customer_churn.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv("../data/customer_churn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("../data/customer_churn.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/customer_churn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("../data/customer_churn.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/nihar/OneDrive/Documents/Customer-Retention-Dashboard/data/customer_churn.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Tenure   Product Region  MonthlyCharges  \
# 0        1001  Female   25      12  Internet  North            70.5
# 1        1002    Male   45      24     Phone  South            55.2
# 2        1003  Female   35       8  Internet  North            80.3
# 3        1004    Male   50      36      Both   East            99.9
# 4        1005  Female   29      18     Phone   West            65.4
#
#    TotalCharges Churn
# 0         840.0    No
# 1        1324.8   Yes
# 2         642.4   Yes
# 3        3596.4    No
# 4        1177.2    No

# %%
df.isnull().sum()
# Out:
# CustomerID        0
# Gender            0
# Age               0
# Tenure            0
# Product           0
# Region            0
# MonthlyCharges    0
# TotalCharges      0
# Churn             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      5 non-null      int64
#  1   Gender          5 non-null      object
#  2   Age             5 non-null      int64
#  3   Tenure          5 non-null      int64
#  4   Product         5 non-null      object
#  5   Region          5 non-null      object
#  6   MonthlyCharges  5 non-null      float64
#  7   TotalCharges    5 non-null      float64
#  8   Churn           5 non-null      object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 488.0+ bytes

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Tenure', 'Product', 'Region',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['Totalcharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df['TotalCharges'].isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['TotalCharges'].isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df['TotalCharges'].isnull().sum(
# Out:
#   Cell In[15], line 1
#     df['TotalCharges'].isnull().sum(
#                                     ^
# SyntaxError: incomplete input

# %%
df['TotalCharges'].isnull().sum()
# Out:
# 0

# %%
df.dropna(subset=['Totalcharges'], inplace=True)

# %% [markdown]
#  Churn Distribution

# %%
df['Churn'].value_counts()
# Out:
# No     3
# Yes    2
# Name: Churn, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['Churn'].value_counts().plot(kind='bar', color=['skyblue','salmon'])
# Out:
# <Axes: >

# %%
plt.title("Customer Churn Count")
# Out:
# Text(0.5, 1.0, 'Customer Churn Count')

# %%
plt.ylabel("Number of customers")
# Out:
# Text(0, 0.5, 'Number of customers')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.tight_layout()

# %%
plt.show()

# %% [markdown]
# Churn by Gender

# %%
df.groupby(['Gender','Churn']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
plt.title("Churn by Gender")
# Out:
# Text(0.5, 1.0, 'Churn by Gender')

# %%
plt.ylabel("number of customers")
# Out:
# Text(0, 0.5, 'number of customers')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.tight_layout()

# %%
plt.show()

# %% [markdown]
# Churn by Product

# %%
df.groupby(['Product','Churn'].size().unstack().plot(kind='bar',stacked=True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.groupby(['Product','Churn'].size().unstack().plot(kind='bar',stacked=True))
#
# AttributeError: 'list' object has no attribute 'size'

# %%
df.groupby(['Product', 'Churn']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Product'>

# %%
plt.title("Churn by product")
# Out:
# Text(0.5, 1.0, 'Churn by product')

# %%
plt.ylabel("Number of customers")
# Out:
# Text(0, 0.5, 'Number of customers')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.tight_layout()

# %%
plt.show()

# %%
cd ~/OneDrive/Documents/Customer-Retention-Dashboard
# Out:
# C:\Users\nihar\OneDrive\Documents\Customer-Retention-Dashboard
